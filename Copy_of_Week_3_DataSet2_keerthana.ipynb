# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthana202/Portfolio/blob/main/Copy_of_Week_3_DataSet2_keerthana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7eba775a-51f3-40ac-b8e3-8d277aa9e63f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eba775a-51f3-40ac-b8e3-8d277aa9e63f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("chipotle.tsv",sep='\t')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.choice_description.fillna('Unknown', inplace=True)

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown     $2.39
# ...

# %%
data.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %%
data.choice_description = data.choice_description.str.replace('[',' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown     $2.39
# ...

# %%
data.choice_description = data.choice_description.str.replace(']',' ')

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.quantity.max()
# Out:
# 15

# %%
data.quantity.min()
# Out:
# 1

# %%
data.item_price.max()
# Out:
# '$9.39 '

# %%
data.item_price.min()
# Out:
# '$1.09 '

# %%
data.choice_description.value_counts()
# Out:
# choice_description
# Unknown                                                                                                                                          1228
#  Diet Coke                                                                                                                                        133
#  Coke                                                                                                                                             115
#  Sprite                                                                                                                                            77
#  Fresh Tomato Salsa,  Rice, Black Beans, Cheese, Sour Cream, Lettuce                                                                               41
#                                                                                                                                                  ...
# ...

# %%
data.groupby(['item_name', 'choice_description'])['quantity'].sum().reset_index()
# Out:
#               item_name                                 choice_description  \
# 0     6 Pack Soft Drink                                              Coke
# 1     6 Pack Soft Drink                                         Diet Coke
# 2     6 Pack Soft Drink                                          Lemonade
# 3     6 Pack Soft Drink                                            Nestea
# 4     6 Pack Soft Drink                                            Sprite
# ...                 ...                                                ...
# 1866  Veggie Soft Tacos   Fresh Tomato Salsa,  Black Beans, Cheese, Sou...
# 1867  Veggie Soft Tacos   Fresh Tomato Salsa,  Fajita Vegetables, Rice,...
# 1868  Veggie Soft Tacos   Roasted Chili Corn Salsa (Medium),  Black Bea...
# 1869  Veggie Soft Tacos   Roasted Chili Corn Salsa,  Fajita Vegetables,...
# 1870  Veggie Soft Tacos   Tomatillo Red Chili Salsa,  Fajita Vegetables...
#
#       quantity
# 0           21
# 1           25
# 2            2
# ...

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown     $2.39
# ...

# %%
data.groupby('order_id')['item_name'].nunique().reset_index()
# Out:
#       order_id  item_name
# 0            1          4
# 1            2          1
# 2            3          2
# 3            4          2
# 4            5          2
# ...        ...        ...
# 1829      1830          2
# 1830      1831          3
# 1831      1832          2
# 1832      1833          1
# 1833      1834          1
#
# [1834 rows x 2 columns]

# %%
data.item_name.value_counts()
# Out:
# item_name
# Chicken Bowl                             717
# Chicken Burrito                          546
# Chips and Guacamole                      474
# Steak Burrito                            365
# Canned Soft Drink                        290
# Steak Bowl                               210
# Chips                                    208
# Bottled Water                            155
# Chicken Soft Tacos                       111
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              102
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          90
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown     $2.39
# ...

# %%
data.item_price = data.item_price.str.replace('$',' ')

# %%
data.item_price
# Out:
# 0         2.39
# 1         3.39
# 2         3.39
# 3         2.39
# 4        16.98
#          ...
# 4617     11.75
# 4618     11.75
# 4619     11.25
# 4620      8.75
# 4621      8.75
# Name: item_price, Length: 4563, dtype: object

# %%
data.item_price = '$' + data.item_price.astype(str)

# %%
data.item_price = data.item_price.str.replace('$$',' ')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown    $ 2.39
# ...

# %%
data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''))
# Out:
# <ipython-input-85-0c175d356e69>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''))

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown    $ 2.39
# ...

# %%
data['item_price'] =  '$' + data['item_price'].astype(str)

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown   $$ 2.39
# ...

# %%
data.to_csv('cleaned_chipotle.csv', sep=',')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                               Unknown   $$ 2.39
# ...

# %%
files.download('cleaned_chipotle.csv')

# %%
data.choice_description = data.choice_description.str.replace('Unknown','None')

# %%
data.choice_description.str.split(",",expand= True)
# Out:
#                                      0                    1             2  \
# 0                                 None                 None          None
# 1                          Clementine                  None          None
# 2                               Apple                  None          None
# 3                                 None                 None          None
# 4      Tomatillo-Red Chili Salsa (Hot)          Black Beans          Rice
# ...                                ...                  ...           ...
# 4617                Fresh Tomato Salsa                 Rice   Black Beans
# 4618                Fresh Tomato Salsa                 Rice    Sour Cream
# 4619                Fresh Tomato Salsa    Fajita Vegetables   Pinto Beans
# 4620                Fresh Tomato Salsa    Fajita Vegetables     Lettuce
# 4621                Fresh Tomato Salsa    Fajita Vegetables   Pinto Beans
#
#                 3              4             5             6     7     8     9
# ...

# %%
split_columns = data['choice_description'].str.split(",", expand=True)


split_columns.columns = ['choice_description_1', 'choice_description_2', 'choice_description_3',
                         'choice_description_4', 'choice_description_5', 'choice_description_6',
                         'choice_description_7', 'choice_description_8', 'choice_description_9',
                         'choice_description_10']


data_frame = pd.concat([data, split_columns], axis=1)

# %%
data_frame
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                  None   $$ 2.39
# ...
